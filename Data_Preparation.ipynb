# %% [markdown]
# Dataset: Amazon Sales Dataset
#
# Link: https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset
#
# License:
# CC BY-NC-SA 4.0
#
# Features
#
# product_id - Product ID
#
# product_name - Name of the Product
#
# category - Category of the Product
#
# discounted_price - Discounted
# Price of the Product
#
# actual_price - Actual Price of the Product
#
# discount_percentage - Percentage of Discount for the Product
#
# rating - Rating of the Product
#
# rating_count - Number of people who voted for the Amazon rating
#
# about_product - Description about the Product
#
# user_id - ID of the user who wrote
# review for the Product
#
# user_name - Name of the user who wrote review for the Product
#
# review_id - ID of the user review
#
# review_title - Short review
#
# review_content - Long review
#
# img_link - Image Link of the Product
#
# product_link - Official Website Link of the Product

# %% [markdown]
# **Data Preparation**

# %% [markdown]
# **1. Structure Understanding**

# %% [markdown]
# Load the data

# %%
import pandas as pd
data=pd.read_csv("/content/amazon.csv")
df=pd.DataFrame(data)
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %% [markdown]
# **Data Types**

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# Convert the necessary object data types to integer/numeric

# %%
columns_to_clean = ['discounted_price', 'actual_price',
                 'discount_percentage', 'rating', 'rating_count']

for col in columns_to_clean:
    # Explicitly convert to string type to ensure .str accessor works
    df[col] = df[col].astype(str)
    df[col] = df[col].str.replace('₹', '', regex=False)\
                     .str.replace(',', '', regex=False)\
                     .str.replace('%', '', regex=False)

    df[col] = pd.to_numeric(df[col], errors='coerce')

# %% [markdown]
# Identifying the Numeric and Categorical Columns

# %%
print("\nNumeric Columns:")
print(df.select_dtypes(include='number').columns)

print("\Categorical Columns:")
print(df.select_dtypes(include='object').columns)
# Out:
# Numeric Columns:
# Index(['discounted_price', 'actual_price', 'discount_percentage', 'rating',
#        'rating_count'],
#       dtype='object')
# \Categorical Columns:
# Index(['product_id', 'product_name', 'category', 'about_product', 'user_id',
#        'user_name', 'review_id', 'review_title', 'review_content', 'img_link',
#        'product_link'],
#       dtype='object')
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# /tmp/ipython-input-703/2222843098.py:4: SyntaxWarning: invalid escape sequence '\C'
#   print("\Categorical Columns:")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   int64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# Count the Unique values

# %% [markdown]
# Count the actual unique values

# %%
df['rating'].unique()
# Out:
# array([4.2, 4. , 3.9, 4.1, 4.3, 4.4, 4.5, 3.7, 3.3, 3.6, 3.4, 3.8, 3.5,
#        4.6, 3.2, 5. , 4.7, 3. , 2.8, 3.1, 4.8, 2.3, nan, 2. , 2.6, 2.9])

# %% [markdown]
# Check the duplicates rowise

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Check the duplicates of unique category

# %%
df.duplicated(subset=['product_id']).sum()
# Out:
# np.int64(114)

# %%
df.duplicated(subset=['user_id']).sum()
# Out:
# np.int64(271)

# %%
df.duplicated(subset=['product_id','user_id']).sum()
# Out:
# np.int64(104)

# %%
df.duplicated(subset=['review_id']).sum()
# Out:
# np.int64(271)

# %%
df.duplicated(subset=['product_id','user_id','review_id']).sum()
# Out:
# np.int64(104)

# %%
df.duplicated(subset=['review_id','review_title','review_content']).sum()
# Out:
# np.int64(253)

# %%
df.duplicated(subset=['product_id','user_id']).sum()
# Out:
# np.int64(104)

# %%
df.duplicated(subset=['rating_count']).sum()
# Out:
# np.int64(321)

# %%
df.duplicated(subset=['rating']).sum()
# Out:
# np.int64(1439)

# %% [markdown]
# Handling missing values

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df[df['rating'].isna()]
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# 1279        2499.0                   16     NaN         992.0
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %%
df[df['rating_count'].isna()]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category  discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             199.0
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 282         999.0                   80     3.0           NaN
# 324         999.0                   75     5.0           NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# ...

# %%
df[df["product_id"] == "B08L12N5H1"]
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# 1279        2499.0                   16     NaN         992.0
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %% [markdown]
# Drop the unnecessary columns/attributes

# %%
# Drop unncessary columns/attributes which are not needed for analysis
df.drop([
    'img_link',
    'product_link',
    'user_id',
    'user_name',
    'review_id',
    'review_title',
    'review_content',
    'about_product'
], axis=1, inplace=True)

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count
# 0        1099.0                   64     4.2       24269.0
# ...

# %% [markdown]
# **Feature Engineering**

# %%
#Split the categories
split_cols = df['category'].str.split('|', expand=True)
split_cols.head()
# Out:
#                        0                        1                   2       3  \
# 0  Computers&Accessories  Accessories&Peripherals  Cables&Accessories  Cables
# 1  Computers&Accessories  Accessories&Peripherals  Cables&Accessories  Cables
# 2  Computers&Accessories  Accessories&Peripherals  Cables&Accessories  Cables
# 3  Computers&Accessories  Accessories&Peripherals  Cables&Accessories  Cables
# 4  Computers&Accessories  Accessories&Peripherals  Cables&Accessories  Cables
#
#            4     5     6
# 0  USBCables  None  None
# 1  USBCables  None  None
# 2  USBCables  None  None
# 3  USBCables  None  None
# 4  USBCables  None  None

# %%
df['category'].str.split('|', expand=True).shape
# Out:
# (1465, 7)

# %%
df[['Root (Department)',
    'Category',
    'Sub_category',
    'Sub-sub_category',
    'Product_type']] = split_cols[[0,1,2,3,4]]

df.drop(['category'], axis=1, inplace=True)
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                   64     4.2       24269.0
# 1             199.0         349.0                   43     4.0       43994.0
# 2             199.0        1899.0                   90     3.9        7928.0
# 3             329.0         699.0                   53     4.2       94363.0
# 4             154.0         399.0                   61     4.2       16905.0
#
#        Root (Department)                 Category        Sub_category  \
# ...

# %% [markdown]
# **2. Data Quality Check**

# %% [markdown]
# **Data Cleaning and Text Normalization**

# %%
df['Root (Department)'] = df['Root (Department)'].str.replace('&', ' & ')
df['Category'] = df['Category'].str.replace('&', ' & ')
df['Sub_category'] = df['Sub_category'].str.replace('&', ' & ')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                   64     4.2       24269.0
# 1             199.0         349.0                   43     4.0       43994.0
# 2             199.0        1899.0                   90     3.9        7928.0
# 3             329.0         699.0                   53     4.2       94363.0
# 4             154.0         399.0                   61     4.2       16905.0
#
#          Root (Department)                   Category          Sub_category  \
# ...

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1464.000000
# mean        3125.310874    5444.990635            47.691468     4.096585
# std         6944.304394   10874.826864            21.635905     0.291674
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %% [markdown]
# Handling the missing values logically

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   1
# rating_count             2
# Root (Department)        0
# Category                 0
# Sub_category             8
# Sub-sub_category       165
# Product_type           943
# dtype: int64

# %% [markdown]
# Finding which row has NA values in 'Rating'

# %%
df[df['rating'].isna()]
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 1279            2099.0        2499.0                   16     NaN
#
#       rating_count Root (Department)                  Category  \
# 1279         992.0    Home & Kitchen  Kitchen & HomeAppliances
#
#                    Sub_category   Sub-sub_category Product_type
# 1279  Vacuum,Cleaning & Ironing  Vacuums&FloorCare      Vacuums

# %% [markdown]
# Average rating of all Departments

# %%
df.groupby('Root (Department)')['rating'].mean()
# Out:
# Root (Department)
# Car & Motorbike            3.800000
# Computers & Accessories    4.154967
# Electronics                4.081749
# Health & PersonalCare      4.000000
# Home & Kitchen             4.040716
# HomeImprovement            4.250000
# MusicalInstruments         3.900000
# OfficeProducts             4.309677
# Toys & Games               4.300000
# Name: rating, dtype: float64

# %% [markdown]
# Getting the unique values of the specfic departments sub-category options

# %%
df[df['Root (Department)'] == 'Home & Kitchen']['Sub_category'].unique()
# Out:
# array(['Scrapbooking', 'PaintingMaterials', 'DrawingMaterials',
#        'SmallKitchenAppliances', 'RoomHeaters',
#        'Vacuum,Cleaning & Ironing', 'KitchenTools',
#        'WaterHeaters & Geysers', 'LaundryOrganization', 'Fans',
#        'Coffee,Tea & Espresso', 'WaterPurifiers & Accessories',
#        'AirPurifiers', 'SewingMachines & Accessories', 'Humidifiers',
#        'AirConditioners', 'Parts & Accessories'], dtype=object)

# %%
df[df['Root (Department)'] == 'Home & Kitchen'] \
    .groupby('Sub_category')['rating'] \
    .mean()
# Out:
# Sub_category
# AirConditioners                 4.300000
# AirPurifiers                    4.275000
# Coffee,Tea & Espresso           4.006667
# DrawingMaterials                4.350000
# Fans                            4.088235
# Humidifiers                     3.966667
# KitchenTools                    4.100000
# LaundryOrganization             4.025000
# PaintingMaterials               4.450000
# Parts & Accessories             4.100000
# RoomHeaters                     3.834783
# Scrapbooking                    3.900000
# SewingMachines & Accessories    3.650000
# SmallKitchenAppliances          4.056354
# Vacuum,Cleaning & Ironing       4.076543
# WaterHeaters & Geysers          4.081818
# WaterPurifiers & Accessories    4.050000
# Name: rating, dtype: float64

# %% [markdown]
# Filling the NA values grouping with the department

# %%
df['rating'] = df.groupby('Root (Department)')['rating'] \
                 .transform(lambda x: x.fillna(x.mean()))

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             2
# Root (Department)        0
# Category                 0
# Sub_category             8
# Sub-sub_category       165
# Product_type           943
# dtype: int64

# %% [markdown]
# Checking out the specfic result

# %%
df.iloc[1279]
# Out:
# product_id                                                    B08L12N5H1
# product_name           Eureka Forbes car Vac 100 Watts Powerful Sucti...
# discounted_price                                                  2099.0
# actual_price                                                      2499.0
# discount_percentage                                                   16
# rating                                                          4.040716
# rating_count                                                       992.0
# Root (Department)                                         Home & Kitchen
# Category                                        Kitchen & HomeAppliances
# Sub_category                                   Vacuum,Cleaning & Ironing
# Sub-sub_category                                       Vacuums&FloorCare
# Product_type                                                     Vacuums
# Name: 1279, dtype: object

# %% [markdown]
# Getting the median of the rating count based on the Department

# %%
df.groupby('Root (Department)')['rating_count'].apply(lambda x: x.median())
# Out:
# Root (Department)
# Car & Motorbike             1118.0
# Computers & Accessories     7732.0
# Electronics                10689.0
# Health & PersonalCare       3663.0
# Home & Kitchen              2305.5
# HomeImprovement             4283.0
# MusicalInstruments         44441.0
# OfficeProducts              4426.0
# Toys & Games               15867.0
# Name: rating_count, dtype: float64

# %%
df[df['rating_count'].isna()]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#      discounted_price  actual_price  discount_percentage  rating  \
# 282             199.0         999.0                   80     3.0
# 324             249.0         999.0                   75     5.0
#
#      rating_count        Root (Department)                   Category  \
# 282           NaN  Computers & Accessories  Accessories & Peripherals
# 324           NaN  Computers & Accessories  Accessories & Peripherals
#
#              Sub_category Sub-sub_category Product_type
# 282  Cables & Accessories           Cables    USBCables
# 324  Cables & Accessories           Cables    USBCables

# %% [markdown]
# Filling the NA values of the rating count using median of the depeartment level.

# %%
df['rating_count'] = df.groupby('Root (Department)')['rating_count'] \
                 .transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             8
# Sub-sub_category       165
# Product_type           943
# dtype: int64

# %% [markdown]
# Handling missing values of Sub-Category

# %%
df[df['Sub_category'].isna()]
# Out:
#      product_id                                       product_name  \
# 662  B08HLZ28QC  Oakter Mini UPS for 12V WiFi Router Broadband ...
# 674  B00LVMTA2A  Panasonic CR-2032/5BE Lithium Coin Battery - P...
# 709  B08L879JSN  Acer EK220Q 21.5 Inch (54.61 cm) Full HD (1920...
# 903  B08Y5QJTVK  Duracell CR2025 3V Lithium Coin Battery, 5 pcs...
# 913  B08Y57TPDM  Duracell CR2016 3V Lithium Coin Battery, 5 pcs...
# 922  B08J82K4GX  Samsung 24-inch(60.46cm) FHD Monitor, IPS, 75 ...
# 965  B075DB1F13  Panasonic Eneloop BQ-CC55N Advanced, Smart and...
# 976  B09XXZXQC1  Xiaomi Pad 5| Qualcomm Snapdragon 860| 120Hz R...
#
#      discounted_price  actual_price  discount_percentage  rating  \
# 662            1199.0        3490.0                   66     4.1
# 674             225.0         250.0                   10     4.4
# 709            6299.0       13750.0                   54     4.2
# 903             116.0         200.0                   42     4.4
# ...

# %%
df[['Category', 'Sub_category']].value_counts()
# Out:
# Category                   Sub_category
# Accessories & Peripherals  Cables & Accessories         240
# Kitchen & HomeAppliances   SmallKitchenAppliances       181
# HomeTheater,TV & Video     Accessories                   86
# Mobiles & Accessories      MobileAccessories             84
# Kitchen & HomeAppliances   Vacuum,Cleaning & Ironing     82
#                                                        ...
# HomeTheater,TV & Video     AVReceivers & Amplifiers       1
# Kitchen & Dining           KitchenTools                   1
# Laptops                    TraditionalLaptops             1
# NetworkingDevices          DataCards & Dongles            1
# PowerAccessories           SurgeProtectors                1
# Name: count, Length: 74, dtype: int64

# %%
df['Sub_category'] = df.groupby('Category')['Sub_category'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.iloc[674]
# Out:
# product_id                                                    B00LVMTA2A
# product_name           Panasonic CR-2032/5BE Lithium Coin Battery - P...
# discounted_price                                                   225.0
# actual_price                                                       250.0
# discount_percentage                                                   10
# rating                                                               4.4
# rating_count                                                     26556.0
# Root (Department)                                            Electronics
# Category                       GeneralPurposeBatteries & BatteryChargers
# Sub_category                                         DisposableBatteries
# Sub-sub_category                                                    None
# Product_type                                                        None
# Name: 674, dtype: object

# %%
df[df['Category'] == 'GeneralPurposeBatteries & BatteryChargers']['Sub_category'].value_counts()
# Out:
# Sub_category
# DisposableBatteries      11
# RechargeableBatteries     3
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             3
# Sub-sub_category       165
# Product_type           943
# dtype: int64

# %%
df[df['Sub_category'].isna()]
# Out:
#      product_id                                       product_name  \
# 709  B08L879JSN  Acer EK220Q 21.5 Inch (54.61 cm) Full HD (1920...
# 922  B08J82K4GX  Samsung 24-inch(60.46cm) FHD Monitor, IPS, 75 ...
# 976  B09XXZXQC1  Xiaomi Pad 5| Qualcomm Snapdragon 860| 120Hz R...
#
#      discounted_price  actual_price  discount_percentage  rating  \
# 709            6299.0       13750.0                   54     4.2
# 922           10099.0       19110.0                   47     4.3
# 976           26999.0       37999.0                   29     4.6
#
#      rating_count        Root (Department)  Category Sub_category  \
# 709        2014.0  Computers & Accessories  Monitors         None
# 922        2623.0  Computers & Accessories  Monitors         None
# 976        2886.0  Computers & Accessories   Tablets         None
#
#     Sub-sub_category Product_type
# 709             None         None
# 922             None         None
# 976             None         None

# %%
df[df['Category'] == 'Monitors']['Sub_category'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[df['Category'] == 'Tablets']['Sub_category'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[['Root (Department)', 'Sub_category']].value_counts()
# Out:
# Root (Department)        Sub_category
# Computers & Accessories  Cables & Accessories          240
# Home & Kitchen           SmallKitchenAppliances        181
# Electronics              Accessories                    97
#                          MobileAccessories              84
# Home & Kitchen           Vacuum,Cleaning & Ironing      82
#                                                       ...
#                          Parts & Accessories             1
#                          Scrapbooking                    1
# HomeImprovement          Adapters & Multi-Outlets        1
#                          CordManagement                  1
# Toys & Games             Drawing & PaintingSupplies      1
# Name: count, Length: 72, dtype: int64

# %%
df['Sub_category'] = df.groupby('Root (Department)')['Sub_category'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             0
# Sub-sub_category       165
# Product_type           943
# dtype: int64

# %%
df[df['Category'] == 'Monitors']['Sub_category'].value_counts()
# Out:
# Sub_category
# Cables & Accessories    2
# Name: count, dtype: int64

# %% [markdown]
# Handling missing values of Sub-Sub Category

# %%
df[['Category', 'Sub_category','Sub-sub_category']].value_counts()
# Out:
# Category                          Sub_category                Sub-sub_category
# Accessories & Peripherals         Cables & Accessories        Cables                        237
# Mobiles & Accessories             Smartphones & BasicMobiles  Smartphones                    68
# HomeTheater,TV & Video            Televisions                 SmartTelevisions               63
# Kitchen & HomeAppliances          Vacuum,Cleaning & Ironing   Irons,Steamers&Accessories     58
# Headphones,Earbuds & Accessories  Headphones                  In-Ear                         52
#                                                                                            ...
# NetworkingDevices                 NetworkAdapters             PowerLANAdapters                1
# OfficePaperProducts               Paper                       Copy&PrintingPaper              1
# OfficeElectronics                 Calculators                 Financial&Business              1
# ...

# %%
df[df['Sub-sub_category'] == 'TonerCartridges']
# Out:
#      product_id                                       product_name  \
# 987  B07KNM95JK  Foxin FTC 12A / Q2612A Black Laser Toner Cartr...
#
#      discounted_price  actual_price  discount_percentage  rating  \
# 987             598.0        1150.0                   48     4.1
#
#      rating_count        Root (Department)                     Category  \
# 987        2535.0  Computers & Accessories  Printers,Inks & Accessories
#
#                  Sub_category Sub-sub_category Product_type
# 987  Inks,Toners & Cartridges  TonerCartridges         None

# %%
df[df['Sub-sub_category'].isna()]
# Out:
#       product_id                                       product_name  \
# 157   B088Z1YWBC  EGate i9 Pro-Max 1080p Native Full HD Projecto...
# 210   B0BLV1GNLN  WZATCO Pixel | Portable LED Projector | Native...
# 268   B0978V2CP6  Cubetek 3 in 1 LCD Display V5.0 Bluetooth Tran...
# 299   B0BNDD9TN6  WANBO X1 Pro (Upgraded) | Native 1080P Full HD...
# 334   B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# ...          ...                                                ...
# 1100  B00KRCBA6E  Maharaja Whiteline Lava Neo 1200-Watts Halogen...
# 1224  B08S6RKT4L  Balzano High Speed Nutri Blender/Mixer/Smoothi...
# 1274  B01M69WCZ6  Allin Exporters J66 Ultrasonic Humidifier Cool...
# 1407  B09P182Z2H  AGARO Glory Cool Mist Ultrasonic Humidifier, 4...
# 1445  B0B97D658R  Larrito wooden Cool Mist Humidifiers Essential...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 157             9490.0       15990.0                   41     3.9
# ...

# %%
df['Sub-sub_category'] = df.groupby(['Category', 'Sub_category'])['Sub-sub_category'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.iloc[1224]
# Out:
# product_id                                                    B08S6RKT4L
# product_name           Balzano High Speed Nutri Blender/Mixer/Smoothi...
# discounted_price                                                  2599.0
# actual_price                                                      4290.0
# discount_percentage                                                   39
# rating                                                               4.4
# rating_count                                                      2116.0
# Root (Department)                                         Home & Kitchen
# Category                                        Kitchen & HomeAppliances
# Sub_category                                      SmallKitchenAppliances
# Sub-sub_category                              Kettles&HotWaterDispensers
# Product_type                                                        None
# Name: 1224, dtype: object

# %%
df[df['Sub-sub_category']=='Kettles&HotWaterDispensers'][['Category', 'Sub_category']].value_counts()
# Out:
# Category                  Sub_category
# Kitchen & HomeAppliances  SmallKitchenAppliances    33
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             0
# Sub-sub_category       156
# Product_type           943
# dtype: int64

# %%
df[df['Sub-sub_category'].isna()]
# Out:
#       product_id                                       product_name  \
# 157   B088Z1YWBC  EGate i9 Pro-Max 1080p Native Full HD Projecto...
# 210   B0BLV1GNLN  WZATCO Pixel | Portable LED Projector | Native...
# 268   B0978V2CP6  Cubetek 3 in 1 LCD Display V5.0 Bluetooth Tran...
# 299   B0BNDD9TN6  WANBO X1 Pro (Upgraded) | Native 1080P Full HD...
# 334   B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# ...          ...                                                ...
# 1012  B014SZPBM4           Duracell Ultra Alkaline D Battery, 2 Pcs
# 1014  B0B2RBP83P  Lenovo IdeaPad 3 11th Gen Intel Core i3 15.6" ...
# 1274  B01M69WCZ6  Allin Exporters J66 Ultrasonic Humidifier Cool...
# 1407  B09P182Z2H  AGARO Glory Cool Mist Ultrasonic Humidifier, 4...
# 1445  B0B97D658R  Larrito wooden Cool Mist Humidifiers Essential...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 157             9490.0       15990.0                   41     3.9
# ...

# %%
df[['Category','Sub-sub_category']].value_counts()
# Out:
# Category                          Sub-sub_category
# Accessories & Peripherals         Cables                        237
# Mobiles & Accessories             Smartphones                    68
# HomeTheater,TV & Video            SmartTelevisions               63
# Kitchen & HomeAppliances          Irons,Steamers&Accessories     58
# Headphones,Earbuds & Accessories  In-Ear                         52
#                                                                ...
# NetworkingDevices                 PowerLANAdapters                1
# OfficePaperProducts               Copy&PrintingPaper              1
# OfficeElectronics                 Financial&Business              1
# Printers,Inks & Accessories       InkjetInkRefills&Kits           1
#                                   TonerCartridges                 1
# Name: count, Length: 138, dtype: int64

# %%
df['Sub-sub_category'] = df.groupby(['Category'])['Sub-sub_category'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             0
# Sub-sub_category       122
# Product_type           943
# dtype: int64

# %%
df[['Sub_category','Sub-sub_category']].value_counts()
# Out:
# Sub_category                Sub-sub_category
# Cables & Accessories        Cables                        237
# Smartphones & BasicMobiles  Smartphones                    68
# Televisions                 SmartTelevisions               63
# Vacuum,Cleaning & Ironing   Irons,Steamers&Accessories     58
# Headphones                  In-Ear                         52
#                                                          ...
# SmallKitchenAppliances      YogurtMakers                    1
#                             StandMixers                     1
# TabletAccessories           Stands                          1
# UninterruptedPowerSupplies  Cables                          1
# VideoCameras                DomeCameras                     1
# Name: count, Length: 151, dtype: int64

# %%
df['Sub-sub_category'] = df.groupby(['Sub_category'])['Sub-sub_category'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             0
# Sub-sub_category       119
# Product_type           943
# dtype: int64

# %%
df[['Root (Department)','Sub-sub_category']].value_counts()
# Out:
# Root (Department)        Sub-sub_category
# Computers & Accessories  Cables                        249
# Electronics              Smartphones                    68
#                          SmartTelevisions               67
# Home & Kitchen           Irons,Steamers&Accessories     58
# Electronics              In-Ear                         56
#                                                       ...
# Home & Kitchen           YogurtMakers                    1
# OfficeProducts           Copy&PrintingPaper              1
#                          Basic                           1
#                          Financial&Business              1
# Toys & Games             ColouringPens&Markers           1
# Name: count, Length: 138, dtype: int64

# %%
df['Sub-sub_category'] = df.groupby(['Root (Department)'])['Sub-sub_category'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             0
# Sub-sub_category         4
# Product_type           943
# dtype: int64

# %%
df[df['Sub-sub_category'].isna()]
# Out:
#      product_id                                       product_name  \
# 613  B076B8G5D8  Boya ByM1 Auxiliary Omnidirectional Lavalier C...
# 800  B07JF9B592  MAONO AU-400 Lavalier Auxiliary Omnidirectiona...
# 805  B07WKBD37W  ESnipe Mart Worldwide Travel Adapter with Buil...
# 982  B07R99NBVB  Gizga Essentials Cable Organiser, Cord Managem...
#
#      discounted_price  actual_price  discount_percentage  rating  \
# 613             798.0        1995.0                   60     4.0
# 800             478.0         699.0                   32     3.8
# 805             425.0         999.0                   57     4.0
# 982             249.0         599.0                   58     4.5
#
#      rating_count   Root (Department)     Category              Sub_category  \
# 613       68664.0  MusicalInstruments  Microphones                 Condenser
# 800       20218.0  MusicalInstruments  Microphones                 Condenser
# ...

# %%
df[df['Root (Department)']=='MusicalInstruments']['Sub-sub_category'].unique()
# Out:
# array([None], dtype=object)

# %%
df[df['Category']=='Electrical'][['Sub-sub_category']].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.shape
# Out:
# (1465, 12)

# %% [markdown]
# Drop the rows still having values in Sub-sub Category
#
# This process done because there no relationship between other attributes

# %%
df = df.dropna(subset=['Sub-sub_category'])

# %%
df[df['Sub-sub_category'].isna()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, discounted_price, actual_price, discount_percentage, rating, rating_count, Root (Department), Category, Sub_category, Sub-sub_category, Product_type]
# Index: []

# %%
df.shape
# Out:
# (1461, 12)

# %% [markdown]
# Handling missing values in Prodcut type

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discount_percentage  rating  rating_count  \
# 0             399.0        1099.0                   64     4.2       24269.0
# 1             199.0         349.0                   43     4.0       43994.0
# 2             199.0        1899.0                   90     3.9        7928.0
# 3             329.0         699.0                   53     4.2       94363.0
# 4             154.0         399.0                   61     4.2       16905.0
#
#          Root (Department)                   Category          Sub_category  \
# ...

# %%
df[['Sub-sub_category','Product_type']].value_counts()
# Out:
# Sub-sub_category                 Product_type
# Cables                           USBCables                        233
# Irons,Steamers&Accessories       Irons                             36
# Cables                           HDMICables                        24
# Irons,Steamers&Accessories       LintShavers                       22
# Vacuums&FloorCare                Vacuums                           20
# Kettles&HotWaterDispensers       ElectricKettles                   19
# Chargers                         WallChargers                      16
# Stationery                       Notebooks,WritingPads&Diaries     14
# Kettles&HotWaterDispensers       Kettle&ToasterSets                13
# Stationery                       Pens,Pencils&WritingSupplies      12
# Chargers                         PowerBanks                        12
# Keyboard&MiceAccessories         MousePads                          8
# Maintenance,Upkeep&Repairs       ScreenProtectors                   7
# ...

# %%
df['Product_type'] = df.groupby(['Sub-sub_category'])['Product_type'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             0
# Sub-sub_category         0
# Product_type           884
# dtype: int64

# %%
df[['Sub_category','Product_type']].value_counts()
# Out:
# Sub_category                Product_type
# Cables & Accessories        USBCables               236
# Vacuum,Cleaning & Ironing   Irons                    36
# Accessories                 HDMICables               24
# Vacuum,Cleaning & Ironing   LintShavers              22
# SmallKitchenAppliances      ElectricKettles          20
#                                                    ...
# MobileAccessories           HandlebarMounts           1
#                             Flashes&SelfieLights      1
# TraditionalLaptops          USBCables                 1
# UninterruptedPowerSupplies  USBCables                 1
# Vacuum,Cleaning & Ironing   VacuumAccessories         1
# Name: count, Length: 67, dtype: int64

# %%
df['Product_type'] = df.groupby(['Sub_category'])['Product_type'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             0
# Sub-sub_category         0
# Product_type           570
# dtype: int64

# %%
df['Product_type'] = df.groupby(['Category'])['Product_type'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# Root (Department)        0
# Category                 0
# Sub_category             0
# Sub-sub_category         0
# Product_type           338
# dtype: int64

# %%
df['Product_type'] = df.groupby(['Root (Department)'])['Product_type'] \
                        .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# Root (Department)      0
# Category               0
# Sub_category           0
# Sub-sub_category       0
# Product_type           2
# dtype: int64

# %%
df[df['Product_type'].isna()]
# Out:
#       product_id                                       product_name  \
# 924   B00DJ5N9VK  Faber-Castell Connector Pen Set - Pack of 25 (...
# 1157  B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 924              150.0         150.0                    0     4.3
# 1157            2339.0        4000.0                   42     3.8
#
#       rating_count Root (Department)        Category  \
# 924        15867.0      Toys & Games   Arts & Crafts
# 1157        1118.0   Car & Motorbike  CarAccessories
#
#                     Sub_category       Sub-sub_category Product_type
# 924   Drawing & PaintingSupplies  ColouringPens&Markers         None
# 1157         InteriorAccessories  AirPurifiers&Ionizers         None

# %%
df[df['Category']=='CarAccessories']
# Out:
#       product_id                                       product_name  \
# 1157  B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
#
#       discounted_price  actual_price  discount_percentage  rating  \
# 1157            2339.0        4000.0                   42     3.8
#
#       rating_count Root (Department)        Category         Sub_category  \
# 1157        1118.0   Car & Motorbike  CarAccessories  InteriorAccessories
#
#            Sub-sub_category Product_type
# 1157  AirPurifiers&Ionizers         None

# %% [markdown]
# Drop the rows still having values in Product-Type

# %%
df = df.dropna(subset=['Product_type'])
df.shape
# Out:
# (1459, 12)

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# Root (Department)      0
# Category               0
# Sub_category           0
# Sub-sub_category       0
# Product_type           0
# dtype: int64

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1459.000000    1459.000000          1459.000000  1459.000000
# mean        3135.120925    5461.596491            47.716929     4.096669
# std         6956.725119   10893.774335            21.634482     0.291709
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     812.500000            32.000000     4.000000
# 50%          799.000000    1690.000000            50.000000     4.100000
# 75%         1999.000000    4331.480000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1459.000000
# mean    18277.867032
# std     42788.295174
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17271.500000
# max    426973.000000

# %% [markdown]
# Save the data

# %%
df.to_csv("AmazonCleanedData_Process1.csv", index=False)
